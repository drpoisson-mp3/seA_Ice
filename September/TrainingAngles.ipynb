# %% [markdown]
# # Angles
# General def through dot product
# $$A\cdot B= |A||B|\cos\theta$$
# $$\cos \theta= \frac{A\cdot B} {|A||B|}$$
# and its easy on grids cuz the dot product in cartestian coordinates is simply
# $$A_xB_x+A_y+B_y$$
# So
# $$\cos \theta= \frac {A_xB_x+A_yB_y}{ \sqrt{A_x^2+A_y^2} \sqrt{B_x^2+B_y^2}} $$

# %%
from AIce.functions import trainloader
# [['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE','bath','sin','cos', 'windnorm'],
#             ['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE','bath','sin','cos'],
#             ['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE','bath'],
#             ['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE'],
#             ['u_ERA5','v_ERA5','h_piomas','sic_CDR'],
#             ['u_ERA5','v_ERA5','h_piomas','sic_CDR', 'windnorm'],
#             ['u_ERA5','v_ERA5','h_piomas'],
#             ['u_ERA5','v_ERA5']]

# %%
data,_,_,_,_,_,_=trainloader('../data/DRIFT_DATA_TRAIN.csv',256,['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE','bath','sin','cos', 'windnorm'],target='angle')
# Out:
# c:\Users\testd\miniconda3\envs\mcgill\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in arccos
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# allright angles
# Sin and Cos added
# Bathymetry (bath) normalized by maximum
# x/y (x_EASE, y_EASE) normalized by maximum
# Windnorm normalized by z-score
# Wind components (u/v_ERA5) normalized by z-score
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data,_,_,_,_,_,_=trainloader('../data/DRIFT_DATA_TRAIN.csv',256,['u_ERA5','v_ERA5','h_piomas','sic_CDR','x_EASE','y_EASE','bath','sin','cos', 'windnorm'],target='angle')
#
# File ~\OneDrive\Bureau\McGilles\Code\RechercheMsc\src\AIce\functions.py:200, in trainloader(filename, bs, inputlist, target, log1p, static_threshold, log1pwind, shuffle)
#     197     if i not in inputlist:
#     198         ds=ds.drop(i,axis=1)
# --> 200 labels=[targeted.columns,ds.columns]
#     205 datapd=pd.concat((targeted,ds), axis=1)
#     206 inputtensor=torch.tensor(ds.values, dtype=torch.float32)
#
# UnboundLocalError: cannot access local variable 'targeted' where it is not associated with a value
